# %% [markdown]
# * Apriori Algorithm is a Machine Learning algorithm which is used to gain insight into the structured relationships between different items involved. The most prominent practical application of the algorithm is to recommend products based on the products already present in the user’s cart. Walmart especially has made great use of the algorithm in suggesting products to it’s users.

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules

# %% [markdown]
# #### Read Datasets

# %%
# read and get the first five of sales receipt
sales_receipt = pd. read_csv('dataset/201904 sales reciepts.csv')
sales_receipt.head()
# Out:
#    transaction_id transaction_date transaction_time  sales_outlet_id  \
# 0               7       2019-04-01         12:04:43                3
# 1              11       2019-04-01         15:54:39                3
# 2              19       2019-04-01         14:34:59                3
# 3              32       2019-04-01         16:06:04                3
# 4              33       2019-04-01         19:18:37                3
#
#    staff_id  customer_id instore_yn  order  line_item_id  product_id  \
# 0        12          558          N      1             1          52
# 1        17          781          N      1             1          27
# 2        17          788          Y      1             1          46
# 3        12          683          N      1             1          23
# 4        17           99          Y      1             1          34
#
#    quantity  line_item_amount  unit_price promo_item_yn
# 0         1              2.50        2.50             N
# 1         2              7.00        3.50             N
# 2         2              5.00        2.50             N
# 3         2              5.00        2.50             N
# 4         1              2.45        2.45             N

# %%
# get the product dataset
product = pd.read_csv('dataset/product.csv')
product.head()
# Out:
#    product_id    product_group product_category       product_type  \
# 0           1  Whole Bean/Teas     Coffee beans      Organic Beans
# 1           2  Whole Bean/Teas     Coffee beans  House blend Beans
# 2           3  Whole Bean/Teas     Coffee beans     Espresso Beans
# 3           4  Whole Bean/Teas     Coffee beans     Espresso Beans
# 4           5  Whole Bean/Teas     Coffee beans      Gourmet Beans
#
#                     product  \
# 0       Brazilian - Organic
# 1  Our Old Time Diner Blend
# 2            Espresso Roast
# 3      Primo Espresso Roast
# 4    Columbian Medium Roast
#
#                                  product_description unit_of_measure  \
# 0     It's like Carnival in a cup. Clean and smooth.           12 oz
# 1  Out packed blend of beans that is reminiscent ...           12 oz
# 2          Our house blend for a good espresso shot.            1 lb
# 3   Our primium single source of hand roasted beans.            1 lb
# 4           A smooth cup of coffee any time of day.             1 lb
#
#    current_wholesale_price current_retail_price tax_exempt_yn promo_yn  \
# 0                    14.40              $18.00              Y        N
# 1                    14.40              $18.00              Y        N
# 2                    11.80              $14.75              Y        N
# 3                    16.36              $20.45              Y        N
# 4                    12.00              $15.00              Y        N
#
#   new_product_yn
# 0              N
# 1              N
# 2              N
# 3              N
# 4              N

# %% [markdown]
# ### Data Wrangling

# %%
# get the columns of sales receipt data
sales_receipt.columns
# Out:
# Index(['transaction_id', 'transaction_date', 'transaction_time',
#        'sales_outlet_id', 'staff_id', 'customer_id', 'instore_yn', 'order',
#        'line_item_id', 'product_id', 'quantity', 'line_item_amount',
#        'unit_price', 'promo_item_yn'],
#       dtype='object')

# %%
# select the necessary columns from the sales receipt aand product data
sales_receipt = sales_receipt[['transaction_id', 'transaction_date', 'customer_id', 'sales_outlet_id', 'product_id', 'quantity']]
product = product[['product_id', 'product_category', 'product']]

# %%
# merge sales_receipt and product data on product_id to a single dataser
dataset = pd.merge(sales_receipt, product, on='product_id', how='left')
dataset.head()
# Out:
#    transaction_id transaction_date  customer_id  sales_outlet_id  product_id  \
# 0               7       2019-04-01          558                3          52
# 1              11       2019-04-01          781                3          27
# 2              19       2019-04-01          788                3          46
# 3              32       2019-04-01          683                3          23
# 4              33       2019-04-01           99                3          34
#
#    quantity product_category                      product
# 0         1              Tea    Traditional Blend Chai Rg
# 1         2           Coffee                 Brazilian Lg
# 2         2              Tea        Serenity Green Tea Rg
# 3         2           Coffee  Our Old Time Diner Blend Rg
# 4         1           Coffee     Jamaican Coffee River Sm

# %% [markdown]
# * Remove sizes (Rg, Lg, Sm) from product

# %%
# filter dataset that have any size of Dark chocolate product
dataset[dataset['product'].str.contains('Dark chocolate')]['product'].unique()
# Out:
# array(['Dark chocolate Lg', 'Dark chocolate Rg', 'Dark chocolate'],
#       dtype=object)

# %%
# unique value of the product with sizes
dataset['product'].nunique()
# Out:
# 80

# %%
# Remove the Lg, Rg, Sm from the products
dataset['product'] = dataset['product'].str.replace(' Rg', '')
dataset['product'] = dataset['product'].str.replace(' Lg', '')
dataset['product'] = dataset['product'].str.replace(' Sm', '')

# %%
# unique value of the product without sizes
dataset['product'].nunique()
# Out:
# 45

# %%
# view the products
print(dataset['product'].unique())
# Out:
# ['Traditional Blend Chai' 'Brazilian' 'Serenity Green Tea'
#  'Our Old Time Diner Blend' 'Jamaican Coffee River' 'Ethiopia'
#  'English Breakfast' 'Sustainably Grown Organic' 'Earl Grey' 'Cappuccino'
#  'Espresso shot' 'Latte' 'Dark chocolate' 'Columbian Medium Roast'
#  'Oatmeal Scone' 'Morning Sunrise Chai' 'Peppermint' 'Jumbo Savory Scone'
#  'Lemon Grass' 'Chocolate Chip Biscotti' 'Spicy Eye Opener Chai'
#  'Ginger Biscotti' 'Chocolate Croissant' 'Hazelnut Biscotti'
#  'Cranberry Scone' 'Scottish Cream Scone ' 'Croissant' 'Almond Croissant'
#  'Ginger Scone' 'Ouro Brasileiro shot' 'Organic Decaf Blend'
#  'Chocolate syrup' 'Hazelnut syrup' 'Carmel syrup'
#  'Sugar Free Vanilla syrup' 'Jamacian Coffee River'
#  'Guatemalan Sustainably Grown' 'Civet Cat' 'Chili Mayan'
#  'Primo Espresso Roast' 'Brazilian - Organic' 'I Need My Bean! Diner mug'
#  'Espresso Roast' 'I Need My Bean! T-shirt' 'I Need My Bean! Latte cup']

# %% [markdown]
# * Choose Product Subset that are either food or drinks

# %%
products_to_take = ['Cappuccino', 'Latte', 'Espresso shot', \
                    'Dark chocolate', 'Sugar Free Vanilla syrup', 'Chocolate syrup', \
                    'Carmel syrup', 'Hazelnut syrup', 'Ginger Scone', \
                    'Chocolate Croissant', 'Jumbo Savory Scone', 'Cranberry Scone', 'Hazelnut Biscotti', \
                    'Croissant', 'Almond Croissant', 'Oatmeal Scone', 'Chocolate Chip Biscotti' \
                    'Ginger Biscotti', \
                    ]

# %%
# dataset of the selected above products
dataset = dataset[dataset['product'].isin(products_to_take)]
dataset.head()
# Out:
#     transaction_id transaction_date  customer_id  sales_outlet_id  product_id  \
# 16             108       2019-04-01           65                3          40
# 17             112       2019-04-01           90                3          37
# 20             127       2019-04-01          116                3          41
# 21             134       2019-04-01          189                3          38
# 22             135       2019-04-01          131                3          40
#
#     quantity product_category        product
# 16         1           Coffee     Cappuccino
# 17         2           Coffee  Espresso shot
# 20         2           Coffee     Cappuccino
# 21         2           Coffee          Latte
# 22         1           Coffee     Cappuccino

# %%
# display the products and its category
dataset[['product', 'product_category']].drop_duplicates().reset_index(drop=True)
# Out:
#                      product    product_category
# 0                 Cappuccino              Coffee
# 1              Espresso shot              Coffee
# 2                      Latte              Coffee
# 3             Dark chocolate  Drinking Chocolate
# 4              Oatmeal Scone              Bakery
# 5         Jumbo Savory Scone              Bakery
# 6        Chocolate Croissant              Bakery
# 7          Hazelnut Biscotti              Bakery
# 8            Cranberry Scone              Bakery
# 9                  Croissant              Bakery
# 10          Almond Croissant              Bakery
# 11              Ginger Scone              Bakery
# 12           Chocolate syrup            Flavours
# 13            Hazelnut syrup            Flavours
# 14              Carmel syrup            Flavours
# 15  Sugar Free Vanilla syrup            Flavours
# 16            Dark chocolate  Packaged Chocolate

# %% [markdown]
# * Cleaned transaction for each customer

# %%
# create a transaction column for concatenating transaction_id and customer_id
dataset['transaction'] = dataset['transaction_id'].astype(str) + '_' + dataset['customer_id'].astype(str)
dataset.head()
# Out:
#     transaction_id transaction_date  customer_id  sales_outlet_id  product_id  \
# 16             108       2019-04-01           65                3          40
# 17             112       2019-04-01           90                3          37
# 20             127       2019-04-01          116                3          41
# 21             134       2019-04-01          189                3          38
# 22             135       2019-04-01          131                3          40
#
#     quantity product_category        product transaction
# 16         1           Coffee     Cappuccino      108_65
# 17         2           Coffee  Espresso shot      112_90
# 20         2           Coffee     Cappuccino     127_116
# 21         2           Coffee          Latte     134_189
# 22         1           Coffee     Cappuccino     135_131

# %%
# get the count of each transaction
num_of_items_for_each_transaction = dataset['transaction'].value_counts().reset_index()
num_of_items_for_each_transaction.head()
# Out:
#   transaction  count
# 0       209_0     31
# 1       206_0     30
# 2       204_0     27
# 3       208_0     25
# 4       203_0     24

# %%
# number of just 1 transaction
num_of_items_for_each_transaction[num_of_items_for_each_transaction['count']==1]
# Out:
#      transaction  count
# 2511       969_0      1
# 2512   1130_8146      1
# 2513   1113_8406      1
# 2514    903_8369      1
# 2515      1010_0      1
# ...          ...    ...
# 7803    297_8353      1
# 7804    337_8112      1
# 7805    343_8399      1
# 7806    357_8239      1
# 7807    126_8009      1
#
# [5297 rows x 2 columns]

# %%
# valid transaction of more than 1 item
valid_transactions = num_of_items_for_each_transaction[num_of_items_for_each_transaction['count'] > 1]['transaction'].to_list()
valid_transactions[:10]
# Out:
# ['209_0',
#  '206_0',
#  '204_0',
#  '208_0',
#  '203_0',
#  '207_0',
#  '205_0',
#  '151_0',
#  '202_0',
#  '9_0']

# %%
# get dataset of transaction of more than 1 item.
dataset = dataset[dataset['transaction'].isin(valid_transactions)]
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9404 entries, 34 to 49886
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transaction_id    9404 non-null   int64
#  1   transaction_date  9404 non-null   object
#  2   customer_id       9404 non-null   int64
#  3   sales_outlet_id   9404 non-null   int64
#  4   product_id        9404 non-null   int64
#  5   quantity          9404 non-null   int64
#  6   product_category  9404 non-null   object
#  7   product           9404 non-null   object
#  8   transaction       9404 non-null   object
# dtypes: int64(5), object(4)
# memory usage: 734.7+ KB

# %% [markdown]
# * Product Trends

# %%
# most ordered product_category
dataset['product_category'].value_counts()
# Out:
# product_category
# Bakery                3115
# Coffee                3104
# Flavours              2246
# Drinking Chocolate     917
# Packaged Chocolate      22
# Name: count, dtype: int64

# %%
# most ordered product
dataset['product'].value_counts()
# Out:
# product
# Cappuccino                  1251
# Latte                       1235
# Dark chocolate               939
# Chocolate Croissant          635
# Espresso shot                618
# Sugar Free Vanilla syrup     605
# Chocolate syrup              568
# Carmel syrup                 561
# Hazelnut syrup               512
# Ginger Scone                 412
# Jumbo Savory Scone           356
# Croissant                    353
# Cranberry Scone              349
# Almond Croissant             343
# Hazelnut Biscotti            334
# Oatmeal Scone                333
# Name: count, dtype: int64

# %% [markdown]
# * Popularity Recommendation Engine based on Products and Product_category Columns for any random person

# %%
product_recommendation = dataset.groupby(['product', 'product_category']).count().reset_index()
product_recommendation.head()
# Out:
#                product product_category  transaction_id  transaction_date  \
# 0     Almond Croissant           Bakery             343               343
# 1           Cappuccino           Coffee            1251              1251
# 2         Carmel syrup         Flavours             561               561
# 3  Chocolate Croissant           Bakery             635               635
# 4      Chocolate syrup         Flavours             568               568
#
#    customer_id  sales_outlet_id  product_id  quantity  transaction
# 0          343              343         343       343          343
# 1         1251             1251        1251      1251         1251
# 2          561              561         561       561          561
# 3          635              635         635       635          635
# 4          568              568         568       568          568

# %%
# select product, product_category and transaction_id
product_recommendation = product_recommendation[['product', 'product_category', 'transaction_id']]
product_recommendation = product_recommendation.rename(columns = {'transaction_id' : 'number_of_transactions'})
product_recommendation.head()
# Out:
#                product product_category  number_of_transactions
# 0     Almond Croissant           Bakery                     343
# 1           Cappuccino           Coffee                    1251
# 2         Carmel syrup         Flavours                     561
# 3  Chocolate Croissant           Bakery                     635
# 4      Chocolate syrup         Flavours                     568

# %%
# save the product_recommendation in this directory
product_recommendation.to_csv('api/recommendation_objects/popular_recommendation.csv', index=False)

# %% [markdown]
# ## Apriori Recommendation Engine

# %%
# training dataset
train_basket = dataset.groupby(['transaction', 'product'])['product'].count().reset_index(name='Count')
train_basket.head()
# Out:
#   transaction         product  Count
# 0      1000_0  Dark chocolate      1
# 1      1000_0   Oatmeal Scone      1
# 2   1001_8306      Cappuccino      1
# 3   1001_8306    Carmel syrup      1
# 4      1002_0    Carmel syrup      1

# %%
# realigning the train basket into a wide format and input 0 as missing number
my_basket = train_basket.pivot_table(index='transaction', columns='product', values='Count').fillna(0)
my_basket.head()
# Out:
# product      Almond Croissant  Cappuccino  Carmel syrup  Chocolate Croissant  \
# transaction
# 1000_0                    0.0         0.0           0.0                  0.0
# 1001_8306                 0.0         1.0           1.0                  0.0
# 1002_0                    0.0         0.0           1.0                  0.0
# 1004_5383                 0.0         0.0           0.0                  0.0
# 1005_0                    0.0         0.0           0.0                  0.0
#
# product      Chocolate syrup  Cranberry Scone  Croissant  Dark chocolate  \
# transaction
# 1000_0                   0.0              0.0        0.0             1.0
# 1001_8306                0.0              0.0        0.0             0.0
# 1002_0                   0.0              0.0        0.0             2.0
# 1004_5383                1.0              0.0        0.0             0.0
# 1005_0                   0.0              0.0        0.0             0.0
#
# product      Espresso shot  Ginger Scone  Hazelnut Biscotti  Hazelnut syrup  \
# transaction
# 1000_0                 0.0           0.0                0.0             0.0
# 1001_8306              0.0           0.0                0.0             0.0
# 1002_0                 1.0           1.0                0.0             0.0
# 1004_5383              0.0           0.0                0.0             0.0
# 1005_0                 0.0           0.0                0.0             0.0
#
# product      Jumbo Savory Scone  Latte  Oatmeal Scone  \
# transaction
# 1000_0                      0.0    0.0            1.0
# 1001_8306                   0.0    0.0            0.0
# 1002_0                      0.0    0.0            0.0
# 1004_5383                   0.0    1.0            0.0
# 1005_0                      2.0    1.0            0.0
#
# product      Sugar Free Vanilla syrup
# transaction
# 1000_0                            0.0
# 1001_8306                         0.0
# 1002_0                            0.0
# 1004_5383                         0.0
# 1005_0                            0.0

# %%
# write a for loop over the dataframe to make it 0s and 1s i.e get rid of any number in the dataframe
def encode_units(x):
    if x <= 0:
        return 0
    elif x > 0:
        return 1
    
my_basket_set = my_basket.applymap(encode_units)
my_basket_set.head(10)
# Out:
# /tmp/ipykernel_24609/2021829575.py:8: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   my_basket_set = my_basket.applymap(encode_units)
# product      Almond Croissant  Cappuccino  Carmel syrup  Chocolate Croissant  \
# transaction
# 1000_0                      0           0             0                    0
# 1001_8306                   0           1             1                    0
# 1002_0                      0           0             1                    0
# 1004_5383                   0           0             0                    0
# 1005_0                      0           0             0                    0
# 1005_5559                   0           0             0                    0
# 1006_0                      1           1             0                    0
# 1007_8375                   0           0             0                    0
# 1008_0                      0           0             1                    0
# 1009_5183                   0           0             0                    0
#
# product      Chocolate syrup  Cranberry Scone  Croissant  Dark chocolate  \
# transaction
# 1000_0                     0                0          0               1
# 1001_8306                  0                0          0               0
# 1002_0                     0                0          0               1
# 1004_5383                  1                0          0               0
# 1005_0                     0                0          0               0
# 1005_5559                  0                0          0               0
# 1006_0                     0                0          0               0
# 1007_8375                  0                0          0               0
# 1008_0                     0                0          0               0
# 1009_5183                  0                0          0               0
#
# product      Espresso shot  Ginger Scone  Hazelnut Biscotti  Hazelnut syrup  \
# transaction
# 1000_0                   0             0                  0               0
# 1001_8306                0             0                  0               0
# 1002_0                   1             1                  0               0
# 1004_5383                0             0                  0               0
# 1005_0                   0             0                  0               0
# 1005_5559                0             0                  0               0
# 1006_0                   1             0                  0               0
# 1007_8375                1             0                  0               1
# 1008_0                   0             1                  0               0
# 1009_5183                0             0                  0               0
#
# product      Jumbo Savory Scone  Latte  Oatmeal Scone  \
# transaction
# 1000_0                        0      0              1
# 1001_8306                     0      0              0
# 1002_0                        0      0              0
# 1004_5383                     0      1              0
# 1005_0                        1      1              0
# 1005_5559                     0      1              0
# 1006_0                        0      0              0
# 1007_8375                     0      0              0
# 1008_0                        0      1              0
# 1009_5183                     0      1              0
#
# product      Sugar Free Vanilla syrup
# transaction
# 1000_0                              0
# 1001_8306                           0
# 1002_0                              0
# 1004_5383                           0
# 1005_0                              0
# 1005_5559                           1
# 1006_0                              0
# 1007_8375                           0
# 1008_0                              0
# 1009_5183                           1

# %% [markdown]
# * Note: the mlxtend Apriori recommendation engine expects the above formats

# %%
# instantiate the apriori class
frequent_items = apriori(my_basket_set, min_support=0.05, use_colnames=True)
frequent_items.head(20)
# Out:
# /home/bluemusk/anaconda3/envs/coffeeshop_env/lib/python3.11/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#      support                            itemsets
# 0   0.120271                  (Almond Croissant)
# 1   0.394265                        (Cappuccino)
# 2   0.201513                      (Carmel syrup)
# 3   0.142573               (Chocolate Croissant)
# 4   0.199124                   (Chocolate syrup)
# 5   0.121864                   (Cranberry Scone)
# 6   0.119474                         (Croissant)
# 7   0.279968                    (Dark chocolate)
# 8   0.216647                     (Espresso shot)
# 9   0.138590                      (Ginger Scone)
# 10  0.109518                 (Hazelnut Biscotti)
# 11  0.180804                    (Hazelnut syrup)
# 12  0.120669                (Jumbo Savory Scone)
# 13  0.394265                             (Latte)
# 14  0.115094                     (Oatmeal Scone)
# 15  0.211071          (Sugar Free Vanilla syrup)
# 16  0.056153      (Almond Croissant, Cappuccino)
# 17  0.060534  (Almond Croissant, Dark chocolate)
# 18  0.057348           (Latte, Almond Croissant)
# 19  0.108323          (Carmel syrup, Cappuccino)

# %%
# Association rules aka Market Basket Analysis
rules_basket = association_rules(frequent_items, metric='lift', min_threshold=1, num_itemsets=1)
rules_basket
# Out:
#                      antecedents                   consequents  \
# 0             (Almond Croissant)                  (Cappuccino)
# 1                   (Cappuccino)            (Almond Croissant)
# 2             (Almond Croissant)              (Dark chocolate)
# 3               (Dark chocolate)            (Almond Croissant)
# 4                        (Latte)            (Almond Croissant)
# ..                           ...                           ...
# 77           (Latte, Cappuccino)              (Dark chocolate)
# 78  (Dark chocolate, Cappuccino)                       (Latte)
# 79                       (Latte)  (Dark chocolate, Cappuccino)
# 80              (Dark chocolate)           (Latte, Cappuccino)
# 81                  (Cappuccino)       (Latte, Dark chocolate)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 0             0.120271            0.394265  0.056153    0.466887  1.184196
# 1             0.394265            0.120271  0.056153    0.142424  1.184196
# 2             0.120271            0.279968  0.060534    0.503311  1.797745
# 3             0.279968            0.120271  0.060534    0.216216  1.797745
# 4             0.394265            0.120271  0.057348    0.145455  1.209392
# ..                 ...                 ...       ...         ...       ...
# 77            0.102350            0.279968  0.052170    0.509728  1.820663
# 78            0.100757            0.394265  0.052170    0.517787  1.313295
# 79            0.394265            0.100757  0.052170    0.132323  1.313295
# 80            0.279968            0.102350  0.052170    0.186344  1.820663
# 81            0.394265            0.099164  0.052170    0.132323  1.334392
#
#     representativity  leverage  conviction  zhangs_metric   jaccard  \
# 0                1.0  0.008734    1.136223       0.176811  0.122502
# 1                1.0  0.008734    1.025833       0.256788  0.122502
# 2                1.0  0.026862    1.449664       0.504414  0.178195
# 3                1.0  0.026862    1.122413       0.616289  0.178195
# 4                1.0  0.009929    1.029470       0.285832  0.125436
# ..               ...       ...         ...            ...       ...
# 77               1.0  0.023516    1.468636       0.502144  0.158022
# 78               1.0  0.012446    1.256155       0.265286  0.117806
# 79               1.0  0.012446    1.036381       0.393830  0.117806
# 80               1.0  0.023516    1.103231       0.626013  0.158022
# 81               1.0  0.013074    1.038216       0.413704  0.118231
#
#     certainty  kulczynski
# 0    0.119891    0.304656
# 1    0.025182    0.304656
# 2    0.310185    0.359764
# 3    0.109062    0.359764
# 4    0.028627    0.311138
# ..        ...         ...
# 77   0.319096    0.348036
# 78   0.203920    0.325055
# 79   0.035103    0.325055
# 80   0.093572    0.348036
# 81   0.036810    0.329214
#
# [82 rows x 14 columns]

# %%
# Testing any antecedents by recommending best consequents based off confidence value
rules_basket[rules_basket['antecedents'] == {'Latte'}].sort_values('confidence', ascending=False)
# Out:
#    antecedents                   consequents  antecedent support  \
# 74     (Latte)    (Sugar Free Vanilla syrup)            0.394265
# 30     (Latte)                (Carmel syrup)            0.394265
# 40     (Latte)             (Chocolate syrup)            0.394265
# 70     (Latte)              (Hazelnut syrup)            0.394265
# 48     (Latte)                   (Croissant)            0.394265
# 34     (Latte)         (Chocolate Croissant)            0.394265
# 67     (Latte)                (Ginger Scone)            0.394265
# 4      (Latte)            (Almond Croissant)            0.394265
# 44     (Latte)             (Cranberry Scone)            0.394265
# 79     (Latte)  (Dark chocolate, Cappuccino)            0.394265
# 69     (Latte)           (Hazelnut Biscotti)            0.394265
# 72     (Latte)               (Oatmeal Scone)            0.394265
#
#     consequent support   support  confidence      lift  representativity  \
# 74            0.211071  0.114695    0.290909  1.378250               1.0
# 30            0.201513  0.113501    0.287879  1.428584               1.0
# 40            0.199124  0.108722    0.275758  1.384855               1.0
# 70            0.180804  0.106730    0.270707  1.497237               1.0
# 48            0.119474  0.060135    0.152525  1.276636               1.0
# 34            0.142573  0.058144    0.147475  1.034383               1.0
# 67            0.138590  0.058144    0.147475  1.064107               1.0
# 4             0.120271  0.057348    0.145455  1.209392               1.0
# 44            0.121864  0.054162    0.137374  1.127273               1.0
# 79            0.100757  0.052170    0.132323  1.313295               1.0
# 69            0.109518  0.050577    0.128283  1.171339               1.0
# 72            0.115094  0.050577    0.128283  1.114596               1.0
#
#     leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 74  0.031477    1.112592       0.453074  0.233766   0.101198    0.417153
# 30  0.034051    1.121279       0.495277  0.235343   0.108161    0.425560
# 40  0.030214    1.105812       0.458786  0.224322   0.095687    0.410879
# 70  0.035445    1.123274       0.548265  0.227891   0.109745    0.430508
# 48  0.013031    1.038999       0.357733  0.132572   0.037535    0.327929
# 34  0.001933    1.005750       0.054876  0.121464   0.005717    0.277648
# 67  0.003503    1.010421       0.099457  0.122483   0.010314    0.283507
# 4   0.009929    1.029470       0.285832  0.125436   0.028627    0.311138
# 44  0.006115    1.017980       0.186391  0.117241   0.017662    0.290909
# 79  0.012446    1.036381       0.393830  0.117806   0.035103    0.325055
# 69  0.007398    1.021526       0.241485  0.111599   0.021073    0.295051
# 72  0.005200    1.015130       0.169734  0.110243   0.014905    0.283865

# %% [markdown]
# * Get product and product_category into a Json Format

# %%
product_categories = dataset[['product', 'product_category']].drop_duplicates().set_index('product').to_dict()['product_category']
product_categories
# Out:
# {'Cappuccino': 'Coffee',
#  'Jumbo Savory Scone': 'Bakery',
#  'Latte': 'Coffee',
#  'Espresso shot': 'Coffee',
#  'Hazelnut Biscotti': 'Bakery',
#  'Chocolate Croissant': 'Bakery',
#  'Dark chocolate': 'Packaged Chocolate',
#  'Cranberry Scone': 'Bakery',
#  'Croissant': 'Bakery',
#  'Almond Croissant': 'Bakery',
#  'Oatmeal Scone': 'Bakery',
#  'Ginger Scone': 'Bakery',
#  'Chocolate syrup': 'Flavours',
#  'Hazelnut syrup': 'Flavours',
#  'Carmel syrup': 'Flavours',
#  'Sugar Free Vanilla syrup': 'Flavours'}

# %%
rules_basket.head()
# Out:
#           antecedents         consequents  antecedent support  \
# 0  (Almond Croissant)        (Cappuccino)            0.120271
# 1        (Cappuccino)  (Almond Croissant)            0.394265
# 2  (Almond Croissant)    (Dark chocolate)            0.120271
# 3    (Dark chocolate)  (Almond Croissant)            0.279968
# 4             (Latte)  (Almond Croissant)            0.394265
#
#    consequent support   support  confidence      lift  representativity  \
# 0            0.394265  0.056153    0.466887  1.184196               1.0
# 1            0.120271  0.056153    0.142424  1.184196               1.0
# 2            0.279968  0.060534    0.503311  1.797745               1.0
# 3            0.120271  0.060534    0.216216  1.797745               1.0
# 4            0.120271  0.057348    0.145455  1.209392               1.0
#
#    leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 0  0.008734    1.136223       0.176811  0.122502   0.119891    0.304656
# 1  0.008734    1.025833       0.256788  0.122502   0.025182    0.304656
# 2  0.026862    1.449664       0.504414  0.178195   0.310185    0.359764
# 3  0.026862    1.122413       0.616289  0.178195   0.109062    0.359764
# 4  0.009929    1.029470       0.285832  0.125436   0.028627    0.311138

# %%
# Get recommendations and convert to json object

recommendations_json = {}

antecedents = rules_basket['antecedents'].unique()
for antecedent in antecedents:
    df_rec = rules_basket[rules_basket['antecedents']==antecedent]
    df_rec = df_rec.sort_values('confidence',ascending=False)
    key = "_".join(antecedent)
    recommendations_json[key] = []
    for _, row in df_rec.iterrows():
        rec_objects =row['consequents']
        for rec_object in rec_objects:
            already_exists = False
            for current_rec_object in recommendations_json[key]:
                if rec_object == current_rec_object['product']:
                    already_exists=True
            if already_exists:
                continue
            
            rec = {'product':rec_object, 
                   'product_category':product_categories[rec_object],
                   'confidence': row['confidence']
                  }
            recommendations_json[key].append(rec)

# %%
# pprint to see the contents of the above recommendations
import pprint

pprint.pp(recommendations_json)
# Out:
# {'Almond Croissant': [{'product': 'Dark chocolate',
#                        'product_category': 'Packaged Chocolate',
#                        'confidence': 0.5033112582781456},
#                       {'product': 'Latte',
#                        'product_category': 'Coffee',
#                        'confidence': 0.4768211920529801},
#                       {'product': 'Cappuccino',
#                        'product_category': 'Coffee',
#                        'confidence': 0.46688741721854304}],
#  'Cappuccino': [{'product': 'Sugar Free Vanilla syrup',
#                  'product_category': 'Flavours',
#                  'confidence': 0.302020202020202},
#                 {'product': 'Chocolate syrup',
#                  'product_category': 'Flavours',
#                  'confidence': 0.29292929292929293},
#                 {'product': 'Carmel syrup',
#                  'product_category': 'Flavours',
#                  'confidence': 0.27474747474747474},
#                 {'product': 'Hazelnut syrup',
#                  'product_category': 'Flavours',
#                  'confidence': 0.24141414141414141},
#                 {'product': 'Ginger Scone',
#                  'product_category': 'Bakery',
#                  'confidence': 0.1595959595959596},
#                 {'product': 'Chocolate Croissant',
#                  'product_category': 'Bakery',
#                  'confidence': 0.1505050505050505},
#                 {'product': 'Croissant',
#                  'product_category': 'Bakery',
#                  'confidence': 0.1505050505050505},
#                 {'product': 'Jumbo Savory Scone',
#                  'product_category': 'Bakery',
#                  'confidence': 0.14747474747474748},
#                 {'product': 'Almond Croissant',
#                  'product_category': 'Bakery',
#                  'confidence': 0.14242424242424243},
#                 {'product': 'Cranberry Scone',
#                  'product_category': 'Bakery',
#                  'confidence': 0.14040404040404042},
#                 {'product': 'Latte',
#                  'product_category': 'Coffee',
#                  'confidence': 0.13232323232323231},
#                 {'product': 'Dark chocolate',
#                  'product_category': 'Packaged Chocolate',
#                  'confidence': 0.13232323232323231},
#                 {'product': 'Oatmeal Scone',
#                  'product_category': 'Bakery',
#                  'confidence': 0.1313131313131313}],
#  'Dark chocolate': [{'product': 'Espresso shot',
#                      'product_category': 'Coffee',
#                      'confidence': 0.23044096728307256},
#                     {'product': 'Chocolate Croissant',
#                      'product_category': 'Bakery',
#                      'confidence': 0.22617354196301567},
#                     {'product': 'Ginger Scone',
#                      'product_category': 'Bakery',
#                      'confidence': 0.22475106685633003},
#                     {'product': 'Almond Croissant',
#                      'product_category': 'Bakery',
#                      'confidence': 0.2162162162162162},
#                     {'product': 'Cranberry Scone',
#                      'product_category': 'Bakery',
#                      'confidence': 0.2119487908961593},
#                     {'product': 'Carmel syrup',
#                      'product_category': 'Flavours',
#                      'confidence': 0.20768136557610242},
#                     {'product': 'Chocolate syrup',
#                      'product_category': 'Flavours',
#                      'confidence': 0.19914651493598862},
#                     {'product': 'Jumbo Savory Scone',
#                      'product_category': 'Bakery',
#                      'confidence': 0.19345661450924612},
#                     {'product': 'Croissant',
#                      'product_category': 'Bakery',
#                      'confidence': 0.19203413940256048},
#                     {'product': 'Latte',
#                      'product_category': 'Coffee',
#                      'confidence': 0.18634423897581792},
#                     {'product': 'Cappuccino',
#                      'product_category': 'Coffee',
#                      'confidence': 0.18634423897581792},
#                     {'product': 'Oatmeal Scone',
#                      'product_category': 'Bakery',
#                      'confidence': 0.18492176386913228},
#                     {'product': 'Hazelnut Biscotti',
#                      'product_category': 'Bakery',
#                      'confidence': 0.18349928876244667},
#                     {'product': 'Hazelnut syrup',
#                      'product_category': 'Flavours',
#                      'confidence': 0.18207681365576103}],
#  'Latte': [{'product': 'Sugar Free Vanilla syrup',
#             'product_category': 'Flavours',
#             'confidence': 0.2909090909090909},
#            {'product': 'Carmel syrup',
#             'product_category': 'Flavours',
#             'confidence': 0.28787878787878785},
#            {'product': 'Chocolate syrup',
#             'product_category': 'Flavours',
#             'confidence': 0.27575757575757576},
#            {'product': 'Hazelnut syrup',
#             'product_category': 'Flavours',
#             'confidence': 0.2707070707070707},
#            {'product': 'Croissant',
#             'product_category': 'Bakery',
#             'confidence': 0.15252525252525254},
#            {'product': 'Chocolate Croissant',
#             'product_category': 'Bakery',
#             'confidence': 0.14747474747474748},
#            {'product': 'Ginger Scone',
#             'product_category': 'Bakery',
#             'confidence': 0.14747474747474748},
#            {'product': 'Almond Croissant',
#             'product_category': 'Bakery',
#             'confidence': 0.14545454545454545},
#            {'product': 'Cranberry Scone',
#             'product_category': 'Bakery',
#             'confidence': 0.13737373737373737},
#            {'product': 'Dark chocolate',
#             'product_category': 'Packaged Chocolate',
#             'confidence': 0.13232323232323231},
#            {'product': 'Cappuccino',
#             'product_category': 'Coffee',
#             'confidence': 0.13232323232323231},
#            {'product': 'Hazelnut Biscotti',
#             'product_category': 'Bakery',
#             'confidence': 0.12828282828282828},
#            {'product': 'Oatmeal Scone',
#             'product_category': 'Bakery',
#             'confidence': 0.12828282828282828}],
#  'Carmel syrup': [{'product': 'Latte',
#                    'product_category': 'Coffee',
#                    'confidence': 0.5632411067193676},
#                   {'product': 'Cappuccino',
#                    'product_category': 'Coffee',
#                    'confidence': 0.5375494071146245},
#                   {'product': 'Espresso shot',
#                    'product_category': 'Coffee',
#                    'confidence': 0.3162055335968379},
#                   {'product': 'Dark chocolate',
#                    'product_category': 'Packaged Chocolate',
#                    'confidence': 0.28853754940711457}],
#  'Chocolate Croissant': [{'product': 'Dark chocolate',
#                           'product_category': 'Packaged Chocolate',
#                           'confidence': 0.44413407821229056},
#                          {'product': 'Cappuccino',
#                           'product_category': 'Coffee',
#                           'confidence': 0.4162011173184358},
#                          {'product': 'Latte',
#                           'product_category': 'Coffee',
#                           'confidence': 0.40782122905027934}],
#  'Chocolate syrup': [{'product': 'Cappuccino',
#                       'product_category': 'Coffee',
#                       'confidence': 0.5800000000000001},
#                      {'product': 'Latte',
#                       'product_category': 'Coffee',
#                       'confidence': 0.5459999999999999},
#                      {'product': 'Espresso shot',
#                       'product_category': 'Coffee',
#                       'confidence': 0.312},
#                      {'product': 'Dark chocolate',
#                       'product_category': 'Packaged Chocolate',
#                       'confidence': 0.27999999999999997}],
#  'Cranberry Scone': [{'product': 'Dark chocolate',
#                       'product_category': 'Packaged Chocolate',
#                       'confidence': 0.4869281045751634},
#                      {'product': 'Cappuccino',
#                       'product_category': 'Coffee',
#                       'confidence': 0.45424836601307195},
#                      {'product': 'Latte',
#                       'product_category': 'Coffee',
#                       'confidence': 0.4444444444444445}],
#  'Croissant': [{'product': 'Latte',
#                 'product_category': 'Coffee',
#                 'confidence': 0.5033333333333333},
#                {'product': 'Cappuccino',
#                 'product_category': 'Coffee',
#                 'confidence': 0.49666666666666665},
#                {'product': 'Dark chocolate',
#                 'product_category': 'Packaged Chocolate',
#                 'confidence': 0.45}],
#  'Ginger Scone': [{'product': 'Cappuccino',
#                    'product_category': 'Coffee',
#                    'confidence': 0.4540229885057472},
#                   {'product': 'Dark chocolate',
#                    'product_category': 'Packaged Chocolate',
#                    'confidence': 0.4540229885057472},
#                   {'product': 'Latte',
#                    'product_category': 'Coffee',
#                    'confidence': 0.41954022988505746}],
#  'Hazelnut syrup': [{'product': 'Latte',
#                      'product_category': 'Coffee',
#                      'confidence': 0.5903083700440528},
#                     {'product': 'Cappuccino',
#                      'product_category': 'Coffee',
#                      'confidence': 0.526431718061674},
#                     {'product': 'Espresso shot',
#                      'product_category': 'Coffee',
#                      'confidence': 0.3215859030837004},
#                     {'product': 'Dark chocolate',
#                      'product_category': 'Packaged Chocolate',
#                      'confidence': 0.2819383259911894}],
#  'Jumbo Savory Scone': [{'product': 'Cappuccino',
#                          'product_category': 'Coffee',
#                          'confidence': 0.4818481848184818},
#                         {'product': 'Dark chocolate',
#                          'product_category': 'Packaged Chocolate',
#                          'confidence': 0.44884488448844884}],
#  'Oatmeal Scone': [{'product': 'Cappuccino',
#                     'product_category': 'Coffee',
#                     'confidence': 0.4498269896193771},
#                    {'product': 'Dark chocolate',
#                     'product_category': 'Packaged Chocolate',
#                     'confidence': 0.4498269896193771},
#                    {'product': 'Latte',
#                     'product_category': 'Coffee',
#                     'confidence': 0.4394463667820069}],
#  'Sugar Free Vanilla syrup': [{'product': 'Cappuccino',
#                                'product_category': 'Coffee',
#                                'confidence': 0.5641509433962264},
#                               {'product': 'Latte',
#                                'product_category': 'Coffee',
#                                'confidence': 0.5433962264150943},
#                               {'product': 'Espresso shot',
#                                'product_category': 'Coffee',
#                                'confidence': 0.30566037735849055}],
#  'Espresso shot': [{'product': 'Dark chocolate',
#                     'product_category': 'Packaged Chocolate',
#                     'confidence': 0.2977941176470588},
#                    {'product': 'Sugar Free Vanilla syrup',
#                     'product_category': 'Flavours',
#                     'confidence': 0.2977941176470588},
#                    {'product': 'Carmel syrup',
#                     'product_category': 'Flavours',
#                     'confidence': 0.2941176470588235},
#                    {'product': 'Chocolate syrup',
#                     'product_category': 'Flavours',
#                     'confidence': 0.2867647058823529},
#                    {'product': 'Hazelnut syrup',
#                     'product_category': 'Flavours',
#                     'confidence': 0.26838235294117646}],
#  'Hazelnut Biscotti': [{'product': 'Dark chocolate',
#                         'product_category': 'Packaged Chocolate',
#                         'confidence': 0.4690909090909091},
#                        {'product': 'Latte',
#                         'product_category': 'Coffee',
#                         'confidence': 0.4618181818181818}],
#  'Latte_Dark chocolate': [{'product': 'Cappuccino',
#                            'product_category': 'Coffee',
#                            'confidence': 0.5261044176706827}],
#  'Latte_Cappuccino': [{'product': 'Dark chocolate',
#                        'product_category': 'Packaged Chocolate',
#                        'confidence': 0.5097276264591439}],
#  'Dark chocolate_Cappuccino': [{'product': 'Latte',
#                                 'product_category': 'Coffee',
#                                 'confidence': 0.5177865612648221}]}

# %%
# save the recommendation in json format
import json

with open('api/recommendation_objects/apriori_recommendations.json', 'w') as json_file:
    json.dump(recommendations_json, json_file)

# %% [markdown]
# * This ends the recommendation engine with Apriori
